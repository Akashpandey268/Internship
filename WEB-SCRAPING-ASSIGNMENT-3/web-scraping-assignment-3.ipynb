# %% [markdown]
# # Q1. Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# %%
# opening page on automated Edge browser

driver.get("https://www.amazon.in/")

# %%
# Now lets give the input that we wnat to search
# Lets take guitar only

input1=input()
# Out:
# guitar

# %%
#Now lets go the search box 

search_box=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search_box.send_keys(input1)
# and enter input1=Guitar as a input inside the box

# %%
search_button_click=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search_button_click.click()
# clicking on the seach button over here

# %% [markdown]
# # Q2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# %%
# opening page on automated Edge browser

driver.get("https://www.amazon.in/")

# %%
# Now lets give the input that we wnat to search
# Lets take guitar only

input1=input()
# Out:
# guitar

# %%
#Now lets go the search box 

search_box=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search_box.send_keys(input1)
# and enter input1=Guitar as a input inside the box

# %%
search_button_click=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search_button_click.click()
# clicking on the seach button over here

# %%
# scrape all product urls
product_urls = []
start=0
end=3
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements(By.XPATH,'//a[@class = "a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

# %%
len(product_urls)
# Out:
# 179

# %%
# blank list variables   
Brand=[]
product = []
price = []
availability=[]
ReturnExchange=[]
Delivery=[]

# %%
for url in product_urls[:10]: ##loop for every guitar in the list
    driver.get(url)
    time.sleep(2)
    
    try:
        brand= driver.find_element(By.XPATH,'//*[@id="productOverview_feature_div"]/div/table/tbody/tr[1]/td[2]/span')
        Brand.append(brand.text)
    except NoSuchElementException:
        Brand.append('-') 
        
    try:
        exchange = driver.find_element(By.XPATH,'//*[@id="RETURNS_POLICY"]/span/div[2]/a')
        ReturnExchange.append(exchange.text)
    except NoSuchElementException:
        ReturnExchange.append('-') 
    try:
        delivery= driver.find_element(By.XPATH,'//span[@class="a-text-bold"]')
        Delivery.append(delivery.text)
    except NoSuchElementException:
        Delivery.append('-') 
        
    
    try:
        product.append(driver.find_element(By.XPATH,'//span[@id="productTitle"]').text)
    except:
        product.append('-')
    try:
        try:
            price.append(driver.find_element(By.XPATH,'//td[@class="a-span12"]').text)
        except:
            price.append(driver.find_element_by_css_selector('span[class="a-price-whole"]').text)             
    except:
        price.append('-')
    try:
        availability.append( driver.find_element(By.XPATH,'//div[@id="availability"]').text)
    except:
        availability.append('-')

# %%
print(len(Brand),len(ReturnExchange),len(Delivery),len(product),len(price),len(availability))
# Out:
# 10 10 10 10 10 10

# %%
df=pd.DataFrame({'Brand':Brand,'ReturnExchange':ReturnExchange,'Price':price,'Delievery_by':Delivery,'urls':url,'Availability':availability})
df
# Out:
#      Brand      ReturnExchange                           Price  \
# 0  Kadence  7 Days Replacement                       ₹3,999.00
# 1  Kadence  7 Days Replacement  ₹8,999.00\nEnds in 11h 05m 56s
# 2    Brown   7 Days Returnable                               -
# 3   FESTRA  7 Days Replacement       ₹2,560.00\nEnds in 6 days
# 4   Juârez  7 Days Replacement        ₹1,774.00\nEnds in 1 day
# 5   Intern  7 Days Replacement        ₹1,799.00\nEnds in 1 day
# 6   Intern  7 Days Replacement        ₹1,854.00\nEnds in 1 day
# 7    Black  7 Days Replacement                      ₹12,499.00
# 8   YAMAHA  7 Days Replacement        ₹8,999.00\nEnds in 1 day
# 9   HOVNER  7 Days Replacement       ₹4,256.00\nEnds in 6 days
#
#            Delievery_by                                               urls  \
# 0     Sunday, 2 October  https://www.amazon.in/Rosewood-Fretboard-Acous...
# 1     Sunday, 2 October  https://www.amazon.in/Rosewood-Fretboard-Acous...
# 2  Friday, 30 September  https://www.amazon.in/Rosewood-Fretboard-Acous...
# 3   Saturday, 1 October  https://www.amazon.in/Rosewood-Fretboard-Acous...
# 4   Saturday, 1 October  https://www.amazon.in/Rosewood-Fretboard-Acous...
# 5   Saturday, 1 October  https://www.amazon.in/Rosewood-Fretboard-Acous...
# 6   Saturday, 1 October  https://www.amazon.in/Rosewood-Fretboard-Acous...
# 7   Saturday, 1 October  https://www.amazon.in/Rosewood-Fretboard-Acous...
# 8  Wednesday, 5 October  https://www.amazon.in/Rosewood-Fretboard-Acous...
# 9   Saturday, 8 October  https://www.amazon.in/Rosewood-Fretboard-Acous...
#
#   Availability
# 0
# 1    In stock.
# 2    In stock.
# 3    In stock.
# 4    In stock.
# 5    In stock.
# 6    In stock.
# 7    In stock.
# 8    In stock.
# 9    In stock.

# %%
driver.close()

# %% [markdown]
# # Q3. 3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# %%
url='https://images.google.com/'
urls = []    # empty list for image urls to download
data = []    # empty list for storing data
search_item = ["Fruits", "Cars", "Machine Learning","Guitar","Cakes"]
for item in search_item:
    driver.get(url)  # performing a Google search for our selected items
    time.sleep(3)
    search_bar = driver.find_element(By.TAG_NAME,"input")     # finding search bar on Google page   
    search_bar.send_keys(str(item))      # send search item list    
    search_button =driver.find_element(By.XPATH,"//button[@class='Tg7LZd']").click() # now we will click on search button
    
    # scroll the page in order to generate more images on the website
    for _ in range(500):
        driver.execute_script("window.scrollBy(0,100)")        
        imgs = driver.find_elements(By.XPATH,"//img[@class='rg_i Q4LuWd']")
    img_url = []
    for image in imgs:
        source = image.get_attribute('src')
        if source is not None:
                if(source[0:4] == 'http'):
                    img_url.append(source)
    for i in img_url[:10]:      # getting only 100 images each
        urls.append(i)
                    
for i in range(len(urls)):
    if i >= 50:
        break
    print("Obtaining {0} of {1} images".format(i, 50))
    response=requests.get(urls[i])
    file = open(r"D:\images\\"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# Obtaining 0 of 50 images
# Obtaining 1 of 50 images
# Obtaining 2 of 50 images
# Obtaining 3 of 50 images
# Obtaining 4 of 50 images
# Obtaining 5 of 50 images
# Obtaining 6 of 50 images
# Obtaining 7 of 50 images
# Obtaining 8 of 50 images
# Obtaining 9 of 50 images
# Obtaining 10 of 50 images
# Obtaining 11 of 50 images
# Obtaining 12 of 50 images
# Obtaining 13 of 50 images
# Obtaining 14 of 50 images
# Obtaining 15 of 50 images
# Obtaining 16 of 50 images
# Obtaining 17 of 50 images
# Obtaining 18 of 50 images
# Obtaining 19 of 50 images
# Obtaining 20 of 50 images
# Obtaining 21 of 50 images
# Obtaining 22 of 50 images
# Obtaining 23 of 50 images
# Obtaining 24 of 50 images
# Obtaining 25 of 50 images
# Obtaining 26 of 50 images
# Obtaining 27 of 50 images
# Obtaining 28 of 50 images
# Obtaining 29 of 50 images
# Obtaining 30 of 50 images
# Obtaining 31 of 50 images
# Obtaining 32 of 50 images
# Obtaining 33 of 50 images
# Obtaining 34 of 50 images
# Obtaining 35 of 50 images
# Obtaining 36 of 50 images
# Obtaining 37 of 50 images
# Obtaining 38 of 50 images
# Obtaining 39 of 50 images
# Obtaining 40 of 50 images
# Obtaining 41 of 50 images
# Obtaining 42 of 50 images
# Obtaining 43 of 50 images
# Obtaining 44 of 50 images
# Obtaining 45 of 50 images
# Obtaining 46 of 50 images
# Obtaining 47 of 50 images
# Obtaining 48 of 50 images
# Obtaining 49 of 50 images

# %%
driver.close()

# %% [markdown]
# # 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# %%
time.sleep(3)

# opning flipkart.com
driver.get('https://www.flipkart.com/')
time.sleep(3)
try:
    login_X_button = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _2doB4z"]')                      # Button to close login popup
    login_X_button.click()
except NoSuchElementException : 
    print("No Login page")
search_bar = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')    # Finding the search bar using it's xpath
search_bar.clear()               # Clearing the search bar
search_bar.send_keys("pixel")       # Inputing keyword to search
search_button = driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')    # Finding the xpath of search button
search_button.click()
# Out:
# No Login page

# %%
# Fetching urls of phones coming on 1st page
flip_urls = []
urls = driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for url in urls:
    flip_urls.append(url.get_attribute("href"))
    
    
    
#Make empty lists   
flip_dict = {}
flip_dict["Brand"] = []
flip_dict["Smartphone"] = []
flip_dict["Colour"] = []
flip_dict["RAM"] = []
flip_dict["Storage(ROM)"] = []
flip_dict["Primary Camera"] = []
flip_dict["Secondary Camera"] = []
flip_dict["Display Size"] = []
flip_dict["Display Resolution"] = []
flip_dict["Processor"] = []
flip_dict["Processor Cores"] = []
flip_dict["Battery Capacity"] = []
flip_dict["Battery Type"] = []
flip_dict["Price"] = []
flip_dict["URL"] = []

# %%
# Scraping data from each url
for url in flip_urls:
    driver.get(url)    # Saving url                                                     
    print("Scraping URL = ", url)
    flip_dict['URL'].append(url)                                                          # Loading the webpage by url
    time.sleep(2)
    
    try:
        read_more = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')     # Button for expanding the specs
        read_more.click()
    except NoSuchElementException:
        print("Exception Occured. Moving to next page")
    
    try:
        brand = driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')      # Extracting Brand from xpath
        flip_dict["Brand"].append(brand.text.split()[0])
    except NoSuchElementException:
        flip_dict['Brand'].append('-')
        
    try:
        price = driver.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')      # Extracting Price from xpath
        flip_dict['Price'].append(price.text)
    except NoSuchElementException:
        flip_dict['Price'].append('-')
        
    try:
        name = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')      # Extracting Name from xpath
        flip_dict['Smartphone'].append(name.text)
    except NoSuchElementException:
        flip_dict['Smartphone'].append('-')
        
    try:
        color = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')      # Extracting colour from xpath
        flip_dict['Colour'].append(color.text)
    except NoSuchElementException:
        flip_dict['Colour'].append('-')
    
    try:
        disp_chk = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/div')
        if disp_chk.text != "Display Features" : raise NoSuchElementException
        disp_size = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/table[1]/tbody/tr[1]/td[2]/ul/li')  # Extracting Display Size from xpath
        flip_dict['Display Size'].append(disp_size.text)
    except NoSuchElementException:
        flip_dict['Display Size'].append('-')
    
    try:
        disp_chk = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/div')
        if disp_chk.text != "Display Features" : raise NoSuchElementException
        disp_res = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/table[1]/tbody/tr[2]/td[2]/ul/li')     # Extracting Display Resolution from xpath
        flip_dict['Display Resolution'].append(disp_res.text)
    except NoSuchElementException:
        flip_dict['Display Resolution'].append('-')
    
    try:
        pro_chk = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[1]')
        if pro_chk.text != "Processor Type" : raise NoSuchElementException
        processor = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[2]/ul/li')   # Extracting processor from xpath
        flip_dict['Processor'].append(processor.text)
    except NoSuchElementException:
        flip_dict['Processor'].append('-')
    
    try:                                                                                     # Extracting Processor Cores from xpath
        core_chk = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[3]/td[1]')
        if core_chk.text != "Processor Core" :
            core_chk = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[1]')
            if core_chk.text != "Processor Core" : 
                raise NoSuchElementException
            else :
                cores = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[2]/td[2]/ul/li')
        else :
            cores = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][3]/table[1]/tbody/tr[3]/td[2]/ul/li')
        flip_dict['Processor Cores'].append(cores.text)
    except NoSuchElementException:
        flip_dict['Processor Cores'].append('-')
    
    try:
        rom = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[1]/td[2]/ul/li')         # Extracting Storage(ROM) from xpath
        flip_dict['Storage(ROM)'].append(rom.text)
    except NoSuchElementException:
        flip_dict['Storage(ROM)'].append('-')
    
    try:
        ram = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[2]/td[2]/ul/li')                # Extracting RAM from xpath
        flip_dict['RAM'].append(ram.text)
    except NoSuchElementException:
        flip_dict['RAM'].append('-')
    try:                                                                                  
        pri_cam = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[2]/td[2]/ul/li')     # Extracting Camera from xpath
        flip_dict['Primary Camera'].append(pri_cam.text)
    except NoSuchElementException:
        flip_dict['Primary Camera'].append('-')
    
    try:                                                                                    # Extracting Secondary Camera from xpath
        cam_chk = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[1]')
        if cam_chk != "Secondary Camera" : 
            if driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[1]').text == "Secondary Camera":
                sec_cam = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[2]/ul/li')
            else :
                raise NoSuchElementException
        else :
            sec_cam = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[2]/ul/li')
        flip_dict['Secondary Camera'].append(sec_cam.text)
    except NoSuchElementException:
        flip_dict['Secondary Camera'].append('-')
        
    try:
        if driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/div').text != "Battery & Power Features" :   # Extracting Battery Capacity from xpath
            if driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/div').text == "Battery & Power Features" :
                bat_chk = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[1]')
                if bat_chk.text != "Battery Capacity" : raise NoSuchElementException
                bat_cap = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[2]/ul/li')                
            elif driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][8]/div').text == "Battery & Power Features" :     
                bat_chk = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[1]')
                if bat_chk.text != "Battery Capacity" : raise NoSuchElementException
                bat_cap = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[2]/ul/li')
            else:
                raise NoSuchElementException
        else :
            bat_chk = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[1]')
            if bat_chk.text != "Battery Capacity" : raise NoSuchElementException
            bat_cap = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[2]/ul/li')                # Extracting Availability from xpath
        flip_dict['Battery Capacity'].append(bat_cap.text)
    except NoSuchElementException:
        flip_dict['Battery Capacity'].append('-')
    
    try:
        if driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/div').text != "Battery & Power Features" :
            if driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/div').text == "Battery & Power Features" :
                bat_chk = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/table/tbody/tr[2]/td[1]')
                if bat_chk.text != "Battery Type" : raise NoSuchElementException
                bat_typ = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/table/tbody/tr[2]/td[2]/ul/li')
            elif driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][8]/div').text == "Battery & Power Features" :
                bat_chk = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][8]/table/tbody/tr[2]/td[1]')
                if bat_chk.text != "Battery Type" : raise NoSuchElementException
                bat_typ = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][8]/table/tbody/tr[2]/td[2]/ul/li')
            else:
                raise NoSuchElementException
        else :
            bat_chk = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/table/tbody/tr[2]/td[1]')
            if bat_chk.text != "Battery Type" : raise NoSuchElementException
            bat_typ = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/table/tbody/tr[2]/td[2]/ul/li')             # Extracting Battery Type from xpath
        flip_dict['Battery Type'].append(bat_typ.text)
    except NoSuchElementException:
        flip_dict['Battery Type'].append('-')
# Out:
# Scraping URL =  https://www.flipkart.com/google-pixel-6a-charcoal-128-gb/p/itme5ae89135d44e?pid=MOBGFKX5YUXD74Z3&lid=LSTMOBGFKX5YUXD74Z3MXA2OB&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGFKX5YUXD74Z3.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/google-pixel-4a-just-black-128-gb/p/itm023b9677aa45d?pid=MOBFUSBNAZGY7HQU&lid=LSTMOBFUSBNAZGY7HQUWHTF0C&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBFUSBNAZGY7HQU.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/google-pixel-3a-clearly-white-64-gb/p/itmfgk4jfgstaack?pid=MOBFFGFPJSCEXMSG&lid=LSTMOBFFGFPJSCEXMSGODGRZE&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBFFGFPJSCEXMSG.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/realme-c30-denim-black-32-gb/p/itmfcf69b2db5059?pid=MOBGF37G8TGKHFWJ&lid=LSTMOBGF37G8TGKHFWJIST95C&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_4&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGF37G8TGKHFWJ.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/realme-c30-lake-blue-32-gb/p/itmfcf69b2db5059?pid=MOBGF37GTRVMRJVK&lid=LSTMOBGF37GTRVMRJVKRYAJNG&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGF37GTRVMRJVK.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/realme-c30-bamboo-green-32-gb/p/itmfcf69b2db5059?pid=MOBGF37G7FRK8FBJ&lid=LSTMOBGF37G7FRK8FBJLNLFYW&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_6&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGF37G7FRK8FBJ.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/realme-c30-denim-black-32-gb/p/itmfcf69b2db5059?pid=MOBGF37GMBMYRFBK&lid=LSTMOBGF37GMBMYRFBKNVTNSG&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_7&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGF37GMBMYRFBK.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/realme-c30-lake-blue-32-gb/p/itmfcf69b2db5059?pid=MOBGF37GWT4TGVZM&lid=LSTMOBGF37GWT4TGVZM1IFYZO&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_8&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGF37GWT4TGVZM.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/realme-c30-bamboo-green-32-gb/p/itmfcf69b2db5059?pid=MOBGF37GUWGZQYGR&lid=LSTMOBGF37GUWGZQYGRW97HI6&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_9&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGF37GUWGZQYGR.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/realme-c30-locked-airtel-prepaid-bamboo-green-32-gb/p/itm938b2a52e171f?pid=MOBGFCFQXDH5NZGU&lid=LSTMOBGFCFQXDH5NZGUMBWKGV&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_10&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGFCFQXDH5NZGU.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm2a08ebbea3689?pid=MOBGDRHVZN29ZJF4&lid=LSTMOBGDRHVZN29ZJF4QSKOSJ&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_11&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGDRHVZN29ZJF4.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-s21-fe-5g-olive-128-gb/p/itm76e6e65136e17?pid=MOBGCKMEMZE5UJXK&lid=LSTMOBGCKMEMZE5UJXK6LPNPI&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_12&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGCKMEMZE5UJXK.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm2a08ebbea3689?pid=MOBGDRHVMW2UDXZY&lid=LSTMOBGDRHVMW2UDXZYRBYUFR&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_13&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGDRHVMW2UDXZY.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-ice-dawn-128-gb/p/itm2a08ebbea3689?pid=MOBGDRHVZ2F9AAM8&lid=LSTMOBGDRHVZ2F9AAM8DRR9FD&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_14&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGDRHVZ2F9AAM8.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/realme-c30-locked-airtel-prepaid-denim-black-32-gb/p/itm938b2a52e171f?pid=MOBGFCFQTSHGRPYA&lid=LSTMOBGFCFQTSHGRPYATV0I3W&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_15&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGFCFQTSHGRPYA.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-s21-fe-5g-graphite-128-gb/p/itm7be0f72fff180?pid=MOBGBPFZSPRG8GSU&lid=LSTMOBGBPFZSPRG8GSUYZCRY0&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_16&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGBPFZSPRG8GSU.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm2a08ebbea3689?pid=MOBGDRHVHNBBBBP5&lid=LSTMOBGDRHVHNBBBBP5SY2MJL&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_17&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGDRHVHNBBBBP5.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-ice-dawn-128-gb/p/itm2a08ebbea3689?pid=MOBGDRHVKYHCVG7W&lid=LSTMOBGDRHVKYHCVG7WR2M8P3&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_18&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGDRHVKYHCVG7W.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm2a08ebbea3689?pid=MOBGDRHVXFVCGS23&lid=LSTMOBGDRHVXFVCGS23RDLBPG&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_19&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGDRHVXFVCGS23.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-light-sea-green-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HQJZKSX3K&lid=LSTMOBGDC6HQJZKSX3KUVADVY&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_20&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGDC6HQJZKSX3K.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-heart-ocean-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HN5VTU6RR&lid=LSTMOBGDC6HN5VTU6RRUSMZV8&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGDC6HN5VTU6RR.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-starry-purple-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HFGCW5PGF&lid=LSTMOBGDC6HFGCW5PGFFKFQIM&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGDC6HFGCW5PGF.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-10-prime-phantom-black-128-gb/p/itm9377b4c936baa?pid=MOBG6RGPPXQFYJ4R&lid=LSTMOBG6RGPPXQFYJ4RW9POLT&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBG6RGPPXQFYJ4R.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-polar-black-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HZHYVX96A&lid=LSTMOBGDC6HZHYVX96AHNLOZE&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=organic&iid=ef8182ab-590a-4be4-a942-2d90b78c7079.MOBGDC6HZHYVX96A.SEARCH&ppt=hp&ppn=homepage&ssid=jszkkvyceo0000001664269331962&qH=ab4086ecd47c568d

# %%
print(len(flip_dict["Brand"]), len(flip_dict["Smartphone"]), len(flip_dict["Processor"]), len(flip_dict["Price"]), len(flip_dict['URL']))
# Out:
# 24 24 24 24 24

# %%
driver.close()

# %% [markdown]
# # Q5: Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# %%
# opening google maps
url = "https://www.google.co.in/maps"
driver.get(url)
time.sleep(2)


search = driver.find_element(By.ID,"searchboxinput")                       # locating search bar
search.clear()                                                             # clearing search bar
time.sleep(2)
search.send_keys("New york")                                                     # entering values in search bar
button = driver.find_element(By.ID,"searchbox-searchbutton")               # locating search button
button.click()                                                             # clicking search button
time.sleep(3)

try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
            lat = lat_lng_list[0]
            lng = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(lat, lng))

except Exception as e:
        print("Error: ", str(e))
# Out:
# URL Extracted:  https://www.google.co.in/maps/place/New+York,+NY,+USA/@25.3067264,82.9882368,14z/data=!4m5!3m4!1s0x89c24fa5d33f083b:0xc80b8f06e177fe62!8m2!3d40.7127753!4d-74.0059728
# Latitude = 25.3067264, Longitude = 82.9882368

# %%
driver.close()

# %% [markdown]
# # 6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in

# %%
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# %%
# opening trak.in
url = "https://trak.in/"
driver.get(url)
time.sleep(2)

# do click on funding deals
button = driver.find_element(By.XPATH,'//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(button)

# Empty lists
fund_dict = {}
fund_dict['Date'] = []
fund_dict['Startup Name'] = []
fund_dict['Industry/Vertical'] = []
fund_dict['Sub-Vertical'] = []
fund_dict['Location'] = []
fund_dict['Investor'] = []
fund_dict['Investment Type'] = []
fund_dict['Amount(in USD)'] = []

for i in range(48,51):
    # Date
    dt = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for d in dt:
        fund_dict['Date'].append(d.text)

    # Startup Name
    sn = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for n in sn:
        fund_dict['Startup Name'].append(n.text)
    
    # Industry/Vertical
    ind = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for n in ind:
        fund_dict['Industry/Vertical'].append(n.text)
    
    # Sub-Vertical
    sv = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for s in sv:
        fund_dict['Sub-Vertical'].append(s.text)

    # Location
    loc = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for l in loc:
        fund_dict['Location'].append(l.text)
    
    # Investor
    inv = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for n in inv:
        fund_dict['Investor'].append(n.text)
    
    # Investment Type
    invt = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for n in invt:
        fund_dict['Investment Type'].append(n.text)
    # Amount
    amt = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for a in amt:
        fund_dict['Amount(in USD)'].append(a.text)
    
fund_df = pd.DataFrame(fund_dict)
fund_df
# Out:
#           Date               Startup Name  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  08/09/2020                     Byju’s
# 21  12/09/2020                  mCaffeine
# 22  09/09/2020                     Qshala
# 23  02/09/2020                      Winzo
# 24  09/09/2020                Hippo Video
# 25  07/09/2020                    Melorra
# 26  07/09/2020                        1mg
# 27  31/08/2020                      mfine
# 28  31/08/2020                       Apna
# 29  03/09/2020                    Railofy
#
#                          Industry/Vertical  \
# 0                               E-commerce
# 1                                  EduTech
# 2                                  EduTech
# 3                                  FinTech
# 4                      Airfare Marketplace
# 5                 Gaming and Entertainment
# 6                              Marketplace
# 7                        Automotive Rental
# 8                               OTT Player
# 9                   Information Technology
# 10                              HealthTech
# 11                              E-commerce
# 12                                FoodTech
# 13                   Hyper-local Logistics
# 14                                 EduTech
# 15                                 EduTech
# 16                                 FinTech
# 17                                 FinTech
# 18                              E-commerce
# 19                                 FinTech
# 20                                 EduTech
# 21                           Personal Care
# 22                                 EduTech
# 23                           Online Gaming
# 24  Video Customer Experience(CX) Platform
# 25                              E-commerce
# 26                              E-commerce
# 27                              HealthTech
# 28                         Human Resources
# 29                          Transportation
#
#                                          Sub-Vertical  \
# 0                                          E-commerce
# 1                                     Online Tutoring
# 2                    Learning Platform for Developers
# 3                                      Group Payments
# 4   Ticketing, Airline Retailing, and Post-Ticketi...
# 5                            Gaming and Entertainment
# 6                           Crowd Sourcing, Freelance
# 7                           Used Car-leasing platform
# 8                            Streaming Social Network
# 9               Internet-of-Things Security Solutions
# 10                           Health care and Wellness
# 11                                    Online Pharmacy
# 12                       Online Food Delivery Service
# 13                           Online Delivery Services
# 14                  Online Climate School, E-learning
# 15                        E-learning, Online Tutoring
# 16                                 Financial Services
# 17                                 Financial Services
# 18                                      Food Delivery
# 19                                 Financial Services
# 20                                    Online Tutoring
# 21                                Skincare & Haircare
# 22                 Online Curiosity Platform for Kids
# 23                                      Online Gaming
# 24             Video Customer Experience(CX) Platform
# 25                               Online Jewelry Store
# 26                                    Online Pharmacy
# 27                      On-Demand Healthcare Services
# 28                               Recruitment Platform
# 29                       WL & RAC protection platform
#
#                                       Location  \
# 0                                    Bangalore
# 1                                    Bangalore
# 2                                    Bangalore
# 3                                       Mumbai
# 4                      Singapore and Bangalore
# 5                                         Pune
# 6                                         Pune
# 7                                      Gurgaon
# 8                           New York and Delhi
# 9                                    Bangalore
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                                   Bangalore
# 14                       Stanford, California,
# 15                                       Noida
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                   Bangalore
# 19                                      Mumbai
# 20                                   Bangalore
# 21                                      Mumbai
# 22                                   Bangalore
# 23                                   New Delhi
# 24  Newark, Delaware, United States of Amercia
# 25                                   Bangalore
# 26                                     Gurgaon
# 27                                   Bangalore
# 28                                   Bangalore
# 29                                      Mumbai
#
#                                              Investor         Investment Type  \
# 0                                         Walmart Inc                     M&A
# 1                                   Coatue Management                Series D
# 2                                         021 Capital            pre-Series A
# 3   Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 4                                    Recruit Co. Ltd.            pre-Series B
# 5            Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 6        Incubate Fund India and Beyond Next Ventures            pre-Series A
# 7                            Early Adapters Syndicate                    Seed
# 8               Raj Mishra, founder of AIT Global Inc                pre-Seed
# 9                              Unicorn India Ventures  Venture-Series Unknown
# 10                                        A1A Company                Series F
# 11         Prasid Uno Family Trust and SC Credit Fund
# 12  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 13                                   Existing Backers             In Progress
# 14  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 15                                        Falcon Edge             In Progress
# 16                                Niyo Solutions Inc.
# 17                            Primrose Hills Ventures
# 18                                     Ascent Capital                 Venture
# 19                              Sequoia India, Unitus                Series A
# 20  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 21  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 22                                 Rainmatter Capital                   Angel
# 23  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 24  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 25                         Shadow Holdings, Lightbox.          Debt Financing
# 26         Gaja Capital, Tata Capital, Partners Group             In Progress
# 27                                   Caretech Pte Inc                Series B
# 28         Lightspeed India and Sequoia Capital India                Series A
# 29                                  Chiratae Ventures                    Seed
#
#      Amount(in USD)
# 0     1,200,000,000
# 1       100,000,000
# 2           934,160
# 3         1,700,000
# 4         3,300,000
# 5           400,000
# 6           974,200
# 7           292,800
# 8           200,000
# 9           500,000
# 10       32,000,000
# 11       23,000,000
# 12        1,560,000
# 13       30,000,000
# 14        1,400,000
# 15  upto 15,000,000
# 16        6,000,000
# 17       10,670,000
# 18       16,200,000
# 19        5,000,000
# 20      500,000,000
# 21        3,000,000
# 22          370,000
# 23       15,500,000
# 24        4,500,000
# 25   upto 8,900,000
# 26      100,000,000
# 27        5,400,000
# 28        8,000,000
# 29          950,000

# %%
driver.close()

# %% [markdown]
# # Q7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# %%
# opening the url digit.in
url = "https://www.digit.in/"
driver.get(url)
time.sleep(2)

# %%
#searching for best laptop
best_gam_laptops = driver.find_element(By.XPATH,"//div[@class='listing_container']//ul//li[9]").click()
time.sleep(4)

# %%
#Creating empty lists
Laptop_Name = []
Operating_sys = []
Display = []
Processor = []
Memory = []
Weight = []
Dimensions = []
Price = []

# %%
# Scraping the data of laptop names
laptop_name= driver.find_elements(By.XPATH,'//div[@class="left_side"]/a/h3')
for name in laptop_name:
    Laptop_Name.append(name.text)
    
    
#Scraping the data of operating system
try:
    op_sys = driver.find_elements(By.XPATH,"//div[@class='product-detail']/div/ul/li[1]/div/div")
    for os in op_sys:
        Operating_sys.append(os.text)
except NoSuchElementException:
    pass


#Scraping data of display of the laptop
try:
    display= driver.find_elements(By.XPATH,"//div[@class='product-detail']/div/ul/li[2]/div/div")
    for disp in display:
        Display.append(disp.text)
except NoSuchElementException:
    pass


#Scraping data of Processor
try:
    processor = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[5]/td[3]")
    for pro in processor:
        Processor.append(pro.text)
except NoSuchElementException:
    pass
#Scraping data of memory
try:
    memory = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")
    for memo in memory:
        Memory.append(memo.text)
except NoSuchElementException:
    pass


#Scraping data of weight
try:
    weight = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[7]/td[3]")
    for wgt in weight:
        Weight.append(wgt.text)
except NoSuchElementException:
    pass


#Scraping data of dimensions
try:
    dimension = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[8]/td[3]")
    for dim in dimension:
        Dimensions.append(dim.text)
except NoSuchElementException:
    pass


#Scraping data of price
try:
    price = driver.find_elements(By.XPATH,"//td[@class='smprice']")
    for pri in price:
        Price.append(pri.text.replace('₹','Rs '))
except NoSuchElementException:
    pass

# %%
print(len(Laptop_Name),len(Operating_sys),len(Display),len(Processor),len(Memory),len(Weight),len(Dimensions),len(Price))
# Out:
# 10 10 10 10 10 10 10 10

# %%
#  DataFrame for scraped data
Gaming_Laptop=pd.DataFrame({})
Gaming_Laptop['Laptop Name'] = Laptop_Name
Gaming_Laptop['Operating system'] = Operating_sys
Gaming_Laptop['Display'] = Display
Gaming_Laptop['Processor'] = Processor
Gaming_Laptop['Memory'] = Memory
Gaming_Laptop['Weight'] = Weight
Gaming_Laptop['Dimensions'] = Dimensions
Gaming_Laptop['Price'] = Price
Gaming_Laptop
# Out:
#                                      Laptop Name    Operating system  \
# 0                           MSI Titan GT77-12UHS  Windows 11 Home OS
# 1                               Alienware X17 R2  Windows 11 Home OS
# 2          Acer Predator Triton 500 SE PT516-52s  Windows 11 Home OS
# 3                        Omen By HP (16-B1371TX)  Windows 11 Home OS
# 4  Acer Predator Helios 300 AN515-45 (NH.QBRSI.0  Windows 11 Home OS
# 5                     MSI Delta 15 (A5EFK-083IN)  Windows 11 Home OS
# 6                        Omen By HP (16-C0141AX)  Windows 11 Home OS
# 7              Lenovo Legion 5i Pro (82RF00MGIN)  Windows 11 Home OS
# 8  Alienware M15 R5 Ryzen Edition Icc-C780001win  Windows 11 Home OS
# 9               Lenovo Slim 7 Gen 6 (82K8002JIN)  Windows 11 Home OS
#
#                        Display        Processor                       Memory  \
# 0  17.3" (3840 x 2160) Display  Windows 11 Home    64 GB DDR5 RAM & 2 TB SSD
# 1  17.3" (1920 x 1080) Display  Windows 11 Home    32 GB DDR5 RAM & 1 TB SSD
# 2    16" (2560 x 1600) Display  Windows 11 Home    32 GB DDR5 RAM & 2 TB SSD
# 3  16.1" (2560 x 1440) Display  Windows 11 Home     8 GB DDR5 RAM & 1 TB SSD
# 4  15.6" (2560 x 1440) Display  Windows 11 Home  16 GB DDR4 RAM & 512 GB SSD
# 5  15.6" (1920 x 1080) Display  Windows 11 Home    16 GB DDR4 RAM & 1 TB SSD
# 6  16.1" (2560 x 1440) Display  Windows 11 Home   16 GB DDR4 RAM & 1 TB NVMe
# 7    16" (2560 x 1600) Display  Windows 11 Home    16 GB DDR5 RAM & 1 TB SSD
# 8  15.6" (1920 x 1080) Display  Windows 11 Home  16 GB DDR4 RAM & 512 GB SSD
# 9         15.6 MP | NA Display  Windows 11 Home    16 GB DDR4 RAM & 1 TB SSD
#
#                                               Weight  \
# 0  16 GB DDR6 NVIDIA GeForce RTX 3080 Ti Graphics...
# 1  16 GB DDR6 NVIDIA GEFORCE RTX 3080 Ti Graphics...
# 2  8 GB DDR6 NVIDIA GeForce RTXTM 3070 Ti Graphic...
# 3   8 GB GDDR6 NVIDIA GeForce RTX 3070 Graphics card
# 4    8 GB DDR6 NVIDIA GeForce RTX 3070 Graphics card
# 5       10 GB DDR6 AMD Radeon RX 6700M Graphics card
# 6      8 GB GDDR6 AMD Radeon™ RX 6600M Graphics card
# 7    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 8    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 9  6 GB DDR6 NVIDIA GeForce 3060 Max-Q Graphics card
#
#                                           Dimensions        Price
# 0        397 x 330 x 23 mm dimension & 3.3 kg weight          N/A
# 1       299 x 359 x 21 mm dimension & 2.96 kg weight  Rs  389,990
# 2      358 x 262 x 19.9 mm dimension & 2.4 kg weight  Rs  300,000
# 3       369 x 248 x 23 mm dimension & 2.32 kg weight  Rs  171,490
# 4      363 x 255 x 23.9 mm dimension & 2.4 kg weight  Rs  172,999
# 5        357 x 247 x 19 mm dimension & 1.9 kg weight  Rs  188,990
# 6    36.92 x 24.8 x 2.3 mm dimension & 2.3 kg weight  Rs  124,990
# 7       360 x 264 x 20 mm dimension & 2.49 kg weight  Rs  163,369
# 8  356.2 x 272.5 x 22.85 mm dimension & 2.69 kg w...  Rs  144,990
# 9        356 x 252 x 16 mm dimension & 1.9 kg weight  Rs  131,790

# %%
#Saving dataset to csv
Gaming_Laptop.to_csv("GamingLaptops.csv")

# %%
driver.close()

# %% [markdown]
# # Q8- Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# %%
#Getting the specified url
url = "https://www.forbes.com/?sh=69e6b8c92254"
driver.get(url)
time.sleep(3)

# %%
#clicking on the explore button
button = driver.find_element(By.XPATH,'//div[@class="_69hVhdY4"]')
button.click()
time.sleep(1)

# %%
#select billionaire  
bill = driver.find_element(By.XPATH,'//div[@class="mpBfVZz3"]/span')
bill.click()
time.sleep(1)

# %%
#select world billionaire  
world_bill= driver.find_element(By.XPATH,'//li[@class="TjJgrPSg _2bNo56RE secondary"]')
world_bill.click()
time.sleep(1)

# %%
#Scraping required data from the web page
#Creating empty lists
Rank = []
Person_Name = []
total_net_worth = []
Age = []
citizenship = []
Source = []
industry = []


while(True):
    #Scraping the data of rank of the billionaires
    rank_tags= driver.find_elements(By.XPATH,"//div[@class='rank']")
    for rank in rank_tags:
        Rank.append(rank.text)
    
    
    #Scraping the data of names of the billionaires
    name_tags= driver.find_elements(By.XPATH,"//div[@class='personName']/div")
    for name in name_tags:
        Person_Name.append(name.text)
    
    
    #Scraping data of age of the billionaires
    age_tags= driver.find_elements(By.XPATH,"//div[@class='age']/div")
    for age in age_tags:
        Age.append(age.text)
    
    #Scraping data of citizenship of the billionaires
    cit_tags= driver.find_elements(By.XPATH,"//div[@class='countryOfCitizenship']")
    for cit in cit_tags:
        citizenship.append(cit.text)
    
    
    #Scraping data of source of income of the billionaires
    sour_tags= driver.find_elements(By.XPATH,"//div[@class='source']")
    for sour in sour_tags:
        Source.append(sour.text)
    
    
    #Scraping data of Industry of the billionaires
    ind_tags= driver.find_elements(By.XPATH,"//div[@class='category']//div")
    for ind in ind_tags:
        industry.append(ind.text)
        
        
    #scraping data of net_worth of billionaires
    net_tags= driver.find_elements(By.XPATH,"//div[@class='netWorth']//div[1]")
    for net in net_tags:
        total_net_worth.append(net.text)
    
    #Clicking on next button
    try:
        next_button = driver.find_element(By.XPATH,"//button[@class='pagination-btn pagination-btn--next ']")
        next_button.click()
    except:
        break
        
#Scraping data of net worth
Net_Worth = []
for i in range(0,len(total_net_worth),2):
    Net_Worth.append(total_net_worth[i])

# %%
#Framing data
Billionaires=pd.DataFrame({})
Billionaires['Rank'] = Rank
Billionaires['Names'] = Person_Name
Billionaires['Net Worth'] = Net_Worth
Billionaires['Age'] = Age
Billionaires['Citizenship'] = citizenship
Billionaires['Source'] = Source
Billionaires['Industry'] = industry
Billionaires
# Out:
#      Rank                     Names Net Worth Age    Citizenship  \
# 0      1.                 Elon Musk    $219 B  50  United States
# 1      2.                Jeff Bezos    $171 B  58  United States
# 2      3.  Bernard Arnault & family    $158 B  73         France
# 3      4.                Bill Gates    $129 B  66  United States
# 4      5.            Warren Buffett    $118 B  91  United States
# ..    ...                       ...       ...  ..            ...
# 195  192.    Marcel Herrmann Telles   $10.3 B  72
# 196  197.                Leon Black     $10 B  70
# 197  197.                Joe Gebbia     $10 B  40  United States
# 198  197.              David Geffen     $10 B  79  United States
# 199  197.                Yu Renrong     $10 B  56          China
#
#                     Source               Industry
# 0                                      Automotive
# 1                                      Technology
# 2                                Fashion & Retail
# 3                                      Technology
# 4                           Finance & Investments
# ..                     ...                    ...
# 195                   beer        Food & Beverage
# 196         private equity  Finance & Investments
# 197                 Airbnb             Technology
# 198  movies, record labels  Media & Entertainment
# 199         semiconductors          Manufacturing
#
# [200 rows x 7 columns]

# %%
driver.close()

# %% [markdown]
# # Q9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video

# %%
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# %%
driver.get("https://www.youtube.com/")
search_tag=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/form/div[1]/div[1]/input')
search_tag.send_keys('Peaches')
search=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/button')
search.click() 
time.sleep(3)

# %%
Peaches_video=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-search/div[1]/ytd-two-column-search-results-renderer/div/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-video-renderer[1]/div[1]/div/div[1]/div/h3/a')
Peaches_video.click()

# %%
comments=[]
time_posteds=[]
Likes=[]
No_of_Likes=[]

# %%
# 1000 time we scroll down by 10000 in order to generate more Comments
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
comment=driver.find_elements(By.ID,"content-text")
for i in comment[0:501]:
       comments.append(i.text)
time_posted=driver.find_elements(By.XPATH,'//yt-formatted-string[@class="published-time-text style-scope ytd-comment-renderer"]')
for i in time_posted[0:501]:
       time_posteds.append(i.text)
like = driver.find_elements(By.XPATH,"//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for i in like:
    Likes.append(i.text)
    
for i in range(1,len(Likes),2)[0:501]:
    No_of_Likes.append(Likes[i])

# %%
print(len(comments),len(time_posteds),len(No_of_Likes))
# Out:
# 40 40 40

# %%
df=pd.DataFrame({'Comments':comments,'Time_Posted':time_posteds,'No_of_Likes':No_of_Likes})
df
# Out:
#                                              Comments           Time_Posted  \
# 0       SUMMER VIBES  Don't Forget to Eat Your Fruits           1 month ago
# 1   kaim always  but my favourite is lemonade & Ca...           1 month ago
# 2   Perfect Mixture of Western and Punjabi Music. ...           3 weeks ago
# 3   Your songs just keep getting better and better...           11 days ago
# 4           Legendary Punjabi singer I had seen ever             8 days ago
# 5   Diljit Paaji Has Passed The Tag Of A Artist......           1 month ago
# 6   Beats will remain in my head till winters atea...           1 month ago
# 7   Diljit Dosanjh never disappoint. New  summer v...           1 month ago
# 8   He Is Always trying Something Different Nd Alw...           1 month ago
# 9    I love the vibe of this song. It hits different            1 month ago
# 10          Noone can make music like punjabi people             5 days ago
# 11  Dude opening me up to a new spectrum of music,...           1 month ago
# 12  On repeat, in my research lab. Like the peache...           1 month ago
# 13  Hands down to DILJIT,RAJ,INTENSE all 3 of them...           1 month ago
# 14  There is a large number of creater in Punjabi ...           1 month ago
# 15  Diljit Dosanjh never disappoint. New summer vi...           1 month ago
# 16                 This man will make history one day           2 weeks ago
# 17  the vibe is awsm and the lyrics , flow everyth...           1 month ago
# 18              Lyrics are always lit..\nDiljit भाई ️           1 month ago
# 19  At this point, even if diljit sings a lullaby ...           1 month ago
# 20  This man is on another level than any other Pu...           11 days ago
# 21  This guy constantly coming up with HITS ..Amaz...           1 month ago
# 22    This man has continuosly gave us a song to vibe           2 weeks ago
# 23  No one can match him. When you knows what exac...           1 month ago
# 24  "When someone support someone from start and t...           1 month ago
# 25  ️️"One of the best thing about dude is that he...           1 month ago
# 26  those two bright eyes, that killer smile, that...           1 month ago
# 27  One of the best thing about dude is that he ne...           1 month ago
# 28  Diljit Dosanjh is a very good person️&mood cha...           2 weeks ago
# 29     INTENSE never fails to impress!  Sickkkk beat!           1 month ago
# 30  Hey, just wanted to say I’m proud how far the ...           1 month ago
# 31  ️"One of the best thing about dude is that he ...           1 month ago
# 32  This guy constantly coming up with HITS ..Amaz...           3 weeks ago
# 33  His songs really give me great vibes and this ...  1 month ago (edited)
# 34    On repeat …music lyrics and Diljit made a blast           1 month ago
# 35  One thing that i have never seen or heard befo...           1 month ago
# 36                       Intense never disappoints ️️           1 month ago
# 37  Fell for this song ...the first time I heard i...           1 month ago
# 38                   Hits after hits  Another banger            1 month ago
# 39  When you support someone from start and than u...           1 month ago
#
#    No_of_Likes
# 0          10K
# 1          634
# 2          151
# 3           27
# 4           37
# 5          117
# 6           38
# 7          475
# 8          227
# 9           48
# 10           1
# 11          17
# 12          29
# 13         205
# 14         206
# 15         239
# 16          42
# 17          14
# 18          24
# 19         175
# 20          22
# 21          82
# 22          42
# 23         131
# 24          33
# 25          27
# 26          13
# 27          13
# 28          12
# 29          88
# 30          19
# 31          25
# 32          25
# 33          49
# 34           4
# 35         184
# 36           9
# 37          16
# 38          73
# 39          82

# %% [markdown]
# # 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description

# %%
# Importing require libary
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
import time
from time import sleep
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import StaleElementReferenceException
import urllib
import pathlib
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# %%
# Opening url in chrome browser
url="https://www.hostelworld.com"
driver.get(url)
time.sleep(2)

# %%
#locating the location search bar
Search = driver.find_element(By.XPATH,'//input[@class="search-input"]')

# Sending input London in search bar
Search.send_keys("London")
time.sleep(1)

# %%
#select london
london = driver.find_element(By.XPATH,'//*[@id="predicted-search-results"]/li[2]/div')
london.click()
time.sleep(2)

# %%
# do click on search button
Search_button = driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[1]/div/div/div[4]/div/div[2]/div/div[5]/button')
Search_button.click()

# %%
#lets find required data
hostel_name = []
distance = []
rating = []
reviews = []
over_all = []
pvt_prices = []
dorms_price = []
facilities = []
description =[]
product_url = []

# %%
for i in driver.find_elements(By.XPATH,"//div[@class = 'pagination-item pagination-current' or @class='pagination-item']"):
    i.click()
    time.sleep(4)

# %%
 #fetching hostel name
try:
        name = driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')
        for i in name:
            hostel_name.append(i.text)
except NoSuchElementException:
        hostel_name.append('-')
len(hostel_name)
hostel_name
# Out:
# ["St Christopher's Village",
#  'Urbany Hostel London',
#  'Safestay London Elephant & Castle',
#  'NX London Hostel',
#  'Saint James Backpackers',
#  "St Christopher's Oasis-Female Only",
#  'Selina Camden',
#  'Britannia Inn Hotel',
#  'City Hotel Carlton',
#  'Elmwood Hotel',
#  'Kip Hotel',
#  'London House Hotel',
#  'Hotel Shepherds Bush London',
#  'Cranbrook Hotel',
#  'Hyde Park Court Hotel',
#  'Park Hotel Essex']

# %%
 #fetching distance from city centre
    
try:
        dist = driver.find_elements(By.XPATH,"//div[@class='subtitle body-3']//a//span[1]")
        for i in dist:
            distance.append(i.text.replace('Hostel - ',''))
except NoSuchElementException:
        distance.append('-')

len(distance)
distance
# Out:
# ['1.8km from city centre',
#  '5.4km from city centre',
#  '1.7km from city centre',
#  '6.1km from city centre',
#  '5.5km from city centre',
#  '1.8km from city centre',
#  '5.5km from city centre',
#  'Hotel - 14.5km from city centre',
#  'Hotel - 1.8km from city centre',
#  'Hotel - 3.2km from city centre',
#  'Hotel - 6.8km from city centre',
#  'Hotel - 5.3km from city centre',
#  'Hotel - 7.6km from city centre',
#  'Hotel - 14.8km from city centre',
#  'Hotel - 4.3km from city centre',
#  'Hotel - 24.1km from city centre']

# %%
#fetch privates from price
try:
    for i in driver.find_elements(By.XPATH,'//div[@class="prices-col"]/a[@class="prices"]/div[1]'):
        pvt_prices.append(i.text)
except NoSuchElementException:    
    pvt_prices.append('-') 
print(len(pvt_prices))
pvt_prices
# Out:
# 16
# ['No Privates Available',
#  'Privates From\nRs17799',
#  'No Privates Available',
#  'Privates From\nRs18307',
#  'Privates From\nRs24718',
#  'Privates From\nRs12870.3 Rs11583',
#  'No Privates Available',
#  'Privates From\nRs10025',
#  'Privates From\nRs16390',
#  'Privates From\nRs20341',
#  'Privates From\nRs11623',
#  'Privates From\nRs31906.99 Rs22335',
#  'Privates From\nRs29054.12 Rs23534',
#  'Privates From\nRs11623',
#  'Privates From\nRs14093',
#  'Privates From\nRs25136']

# %%
#fetching dorms from price
try:
    for i in driver.find_elements(By.XPATH,'//div[@class="prices-col"]/a[@class="prices"]/div[2]'):
        dorms_price.append(i.text)
except NoSuchElementException:    
    dorms_price.append('-') 
print(len(dorms_price))
dorms_price
# Out:
# 16
# ['Dorms From\nRs7957.17 Rs7161',
#  'No Dorms Available',
#  'Dorms From\nRs4681',
#  'Dorms From\nRs9509.38 Rs7608',
#  'Dorms From\nRs6306',
#  'No Dorms Available',
#  'Dorms From\nRs8386.26 Rs7128',
#  'No Dorms Available',
#  'No Dorms Available',
#  'No Dorms Available',
#  'No Dorms Available',
#  'No Dorms Available',
#  'No Dorms Available',
#  'No Dorms Available',
#  'No Dorms Available',
#  'No Dorms Available']

# %%
try:
    for i in driver.find_elements(By.XPATH,'//div[@class="property-card"]/div[@class="property"]/div[1]/div[2]'):
        facilities.append(i.text.replace('\n',', '))
except NoSuchElementException:
        facilities.append('-')
len(facilities)
facilities
# Out:
# ['Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Free Breakfast',
#  'Free WiFi, Free Breakfast, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free Breakfast, Follows Covid-19 sanitation guidance',
#  '',
#  '',
#  'Free WiFi',
#  'Free WiFi',
#  'Free WiFi, Follows Covid-19 sanitation guidance',
#  'Free Breakfast, Follows Covid-19 sanitation guidance',
#  'Free WiFi, Free Breakfast',
#  'Free Breakfast, Follows Covid-19 sanitation guidance']

# %%
# Ratings
try: 
    for i in driver.find_elements(By.XPATH,'//div[@class="bottom-rating"]/a/div/div[1]'):
        if "No" in i.text:
            rating.append("No Ratings")
        else:
            rating.append(i.text)
except NoSuchElementException:
    rating.append('-')
print(len(rating))
rating
# Out:
# 16
# ['8.2',
#  '9.3',
#  '6.9',
#  '7.6',
#  '6.9',
#  '8.2',
#  '8.3',
#  '8.5',
#  '7.5',
#  '7.0',
#  '6.6',
#  '9.4',
#  'No Ratings',
#  'No Ratings',
#  '5.0',
#  '8.0']

# %%
#fetching total reviews
        
try:
    for i in driver.find_elements(By.XPATH,'//div[@class="bottom-rating"]/a/div/div/div[2]'):
        reviews.append(i.text)
except NoSuchElementException:
        reviews.append('-')
print(len(reviews))
reviews
# Out:
# 16
# ['11544 Total Reviews',
#  '477 Total Reviews',
#  '4529 Total Reviews',
#  '1232 Total Reviews',
#  '1828 Total Reviews',
#  '689 Total Reviews',
#  '36 Total Reviews',
#  '23 Total Reviews',
#  '45 Total Reviews',
#  '117 Total Reviews',
#  '54 Total Reviews',
#  '1382 Total Reviews',
#  '0 Total Reviews',
#  '58 Total Reviews',
#  '139 Total Reviews',
#  '109 Total Reviews']

# %%
#fetching overall reviews     
try:
    for i in driver.find_elements(By.XPATH,'//div[@class="bottom-rating"]/a/div/div/div[1]'):
        over_all.append(i.text)
except NoSuchElementException:
        over_all.append('-')
print(len(over_all))
over_all
# Out:
# 16
# ['Fabulous',
#  'Superb',
#  'Good',
#  'Very Good',
#  'Good',
#  'Fabulous',
#  'Fabulous',
#  'Fabulous',
#  'Very Good',
#  'Very Good',
#  'Good',
#  'Superb',
#  'No Rating',
#  'No Rating',
#  'Rating',
#  'Fabulous']

# %%
#fetching property description     
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="description"]'):
        description.append(i.text)
except NoSuchElementException:
        description.append('-')
print(len(description))
description
# Out:
# 16
# ['Hostel - 1.8km from city centre',
#  'Hostel - 5.4km from city centre',
#  'Hostel - 1.7km from city centre',
#  'Hostel - 6.1km from city centre',
#  'Hostel - 5.5km from city centre',
#  'Hostel - 1.8km from city centre',
#  'Hostel - 5.5km from city centre',
#  'Hotel - 14.5km from city centre',
#  'Hotel - 1.8km from city centre',
#  'Hotel - 3.2km from city centre',
#  'Hotel - 6.8km from city centre',
#  'Hotel - 5.3km from city centre',
#  'Hotel - 7.6km from city centre',
#  'Hotel - 14.8km from city centre',
#  'Hotel - 4.3km from city centre',
#  'Hotel - 24.1km from city centre']

# %%
#Creating the DataFrame
df=pd.DataFrame({'hostel_name':hostel_name,'distance':distance,'rating':rating,'reviews':reviews,'over_all':over_all,'pvt_prices':pvt_prices,'dorms_price':dorms_price,'facilities':facilities,'description':description})
df
# Out:
#                            hostel_name                         distance  \
# 0             St Christopher's Village           1.8km from city centre
# 1                 Urbany Hostel London           5.4km from city centre
# 2    Safestay London Elephant & Castle           1.7km from city centre
# 3                     NX London Hostel           6.1km from city centre
# 4              Saint James Backpackers           5.5km from city centre
# 5   St Christopher's Oasis-Female Only           1.8km from city centre
# 6                        Selina Camden           5.5km from city centre
# 7                  Britannia Inn Hotel  Hotel - 14.5km from city centre
# 8                   City Hotel Carlton   Hotel - 1.8km from city centre
# 9                        Elmwood Hotel   Hotel - 3.2km from city centre
# 10                           Kip Hotel   Hotel - 6.8km from city centre
# 11                  London House Hotel   Hotel - 5.3km from city centre
# 12         Hotel Shepherds Bush London   Hotel - 7.6km from city centre
# 13                     Cranbrook Hotel  Hotel - 14.8km from city centre
# 14               Hyde Park Court Hotel   Hotel - 4.3km from city centre
# 15                    Park Hotel Essex  Hotel - 24.1km from city centre
#
#         rating              reviews   over_all  \
# 0          8.2  11544 Total Reviews   Fabulous
# 1          9.3    477 Total Reviews     Superb
# 2          6.9   4529 Total Reviews       Good
# 3          7.6   1232 Total Reviews  Very Good
# 4          6.9   1828 Total Reviews       Good
# 5          8.2    689 Total Reviews   Fabulous
# 6          8.3     36 Total Reviews   Fabulous
# 7          8.5     23 Total Reviews   Fabulous
# 8          7.5     45 Total Reviews  Very Good
# 9          7.0    117 Total Reviews  Very Good
# 10         6.6     54 Total Reviews       Good
# 11         9.4   1382 Total Reviews     Superb
# 12  No Ratings      0 Total Reviews  No Rating
# 13  No Ratings     58 Total Reviews  No Rating
# 14         5.0    139 Total Reviews     Rating
# 15         8.0    109 Total Reviews   Fabulous
#
#                            pvt_prices                   dorms_price  \
# 0               No Privates Available  Dorms From\nRs7957.17 Rs7161
# 1              Privates From\nRs17799            No Dorms Available
# 2               No Privates Available            Dorms From\nRs4681
# 3              Privates From\nRs18307  Dorms From\nRs9509.38 Rs7608
# 4              Privates From\nRs24718            Dorms From\nRs6306
# 5    Privates From\nRs12870.3 Rs11583            No Dorms Available
# 6               No Privates Available  Dorms From\nRs8386.26 Rs7128
# 7              Privates From\nRs10025            No Dorms Available
# 8              Privates From\nRs16390            No Dorms Available
# 9              Privates From\nRs20341            No Dorms Available
# 10             Privates From\nRs11623            No Dorms Available
# 11  Privates From\nRs31906.99 Rs22335            No Dorms Available
# 12  Privates From\nRs29054.12 Rs23534            No Dorms Available
# 13             Privates From\nRs11623            No Dorms Available
# 14             Privates From\nRs14093            No Dorms Available
# 15             Privates From\nRs25136            No Dorms Available
#
#                                            facilities  \
# 0     Free WiFi, Follows Covid-19 sanitation guidance
# 1     Free WiFi, Follows Covid-19 sanitation guidance
# 2     Free WiFi, Follows Covid-19 sanitation guidance
# 3                           Free WiFi, Free Breakfast
# 4   Free WiFi, Free Breakfast, Follows Covid-19 sa...
# 5     Free WiFi, Follows Covid-19 sanitation guidance
# 6                                           Free WiFi
# 7   Free Breakfast, Follows Covid-19 sanitation gu...
# 8
# 9
# 10                                          Free WiFi
# 11                                          Free WiFi
# 12    Free WiFi, Follows Covid-19 sanitation guidance
# 13  Free Breakfast, Follows Covid-19 sanitation gu...
# 14                          Free WiFi, Free Breakfast
# 15  Free Breakfast, Follows Covid-19 sanitation gu...
#
#                         description
# 0   Hostel - 1.8km from city centre
# 1   Hostel - 5.4km from city centre
# 2   Hostel - 1.7km from city centre
# 3   Hostel - 6.1km from city centre
# 4   Hostel - 5.5km from city centre
# 5   Hostel - 1.8km from city centre
# 6   Hostel - 5.5km from city centre
# 7   Hotel - 14.5km from city centre
# 8    Hotel - 1.8km from city centre
# 9    Hotel - 3.2km from city centre
# 10   Hotel - 6.8km from city centre
# 11   Hotel - 5.3km from city centre
# 12   Hotel - 7.6km from city centre
# 13  Hotel - 14.8km from city centre
# 14   Hotel - 4.3km from city centre
# 15  Hotel - 24.1km from city centre

# %%
driver.close()
